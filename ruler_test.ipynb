# %%
import bs4
import os
import requests

# %%
import hashlib
import json

def calculate_checksum(data):
    # Calculate checksum using SHA-256 hashing algorithm
    sha256 = hashlib.sha256()
    sha256.update(data.encode('utf-8'))
    return sha256.hexdigest()

def load_and_check_data(file_path, new_data, encoding = 'utf-8'):
    # Detect if the content is JSON or HTML based on the file extension
    is_json = file_path.lower().endswith('.json')
    try:
        # Read existing content from file
        with open(file_path, 'r', encoding=encoding) as file:
            existing_data = file.read()
            
        if is_json:
            # Decode existing JSON data and new JSON data
            existing_data = json.loads(existing_data)
            new_data = json.loads(new_data)

            # Calculate checksums for existing and new JSON content
            existing_checksum = calculate_checksum(json.dumps(existing_data, sort_keys=True))
            new_checksum = calculate_checksum(json.dumps(new_data, sort_keys=True))
        else:
            # Calculate checksums for existing and new HTML content
            existing_checksum = calculate_checksum(existing_data)
            new_checksum = calculate_checksum(new_data)

        # Compare checksums to check for changes
        if existing_checksum != new_checksum:
            print(f"{ 'JSON' if is_json else 'HTML' } content has changed.")
            # Write new content to file
            with open(file_path, 'w',encoding=encoding) as file:
                if is_json:
                    json.dump(new_data, file, indent=4, sort_keys=True)
                else:
                    file.write(new_data)
            print(f"{ 'JSON' if is_json else 'HTML' } updated successfully.")
            # Return updated content
            return new_data
        else:
            print(f"{ 'JSON' if is_json else 'HTML' } content remains unchanged.")
            # Return existing content
            if is_json:
                return existing_data
            else:
                return existing_data

    except FileNotFoundError:
        # If the file doesn't exist, create it with new content
        with open(file_path, 'w',encoding=encoding) as file:
            if is_json:
                json.dump(json.loads(new_data), file, indent=4, sort_keys=True)
            else:
                file.write(new_data)
        print(f"File created with { 'JSON' if is_json else 'HTML' } content.")
    
        # Return new content
        if is_json: 
            return json.loads(new_data)
        else:
            return new_data

# %%
ruler_url= "https://www.rulers.org/"
rulerorg_html = requests.get(ruler_url)
rulerorg_bs = bs4.BeautifulSoup(rulerorg_html.text)
rulerorg_href_list = ["https://www.rulers.org/"+i.get('href') for i in rulerorg_bs.center.find_all('a', href=True)]
rulerorg_html_name_list = [i.get('href') for i in rulerorg_bs.center.find_all('a', href=True)]
rulerorg_href_list
# Out:
# ['https://www.rulers.org/rula1.html',
#  'https://www.rulers.org/rula2.html',
#  'https://www.rulers.org/rulb1.html',
#  'https://www.rulers.org/rulb2.html',
#  'https://www.rulers.org/rulc1.html',
#  'https://www.rulers.org/rulc2.html',
#  'https://www.rulers.org/rulc3.html',
#  'https://www.rulers.org/rulc4.html',
#  'https://www.rulers.org/ruld.html',
#  'https://www.rulers.org/rule.html',
#  'https://www.rulers.org/rulf.html',
#  'https://www.rulers.org/rulg1.html',
#  'https://www.rulers.org/rulg2.html',
#  'https://www.rulers.org/rulh.html',
#  'https://www.rulers.org/ruli.html',
#  'https://www.rulers.org/ruljk.html',
#  'https://www.rulers.org/rull.html',
#  'https://www.rulers.org/rulm1.html',
#  'https://www.rulers.org/rulm2.html',
#  'https://www.rulers.org/ruln1.html',
#  'https://www.rulers.org/ruln2.html',
#  'https://www.rulers.org/rulp1.html',
#  'https://www.rulers.org/rulp2.html',
#  'https://www.rulers.org/rulqr.html',
#  'https://www.rulers.org/ruls1.html',
#  'https://www.rulers.org/ruls2.html',
#  'https://www.rulers.org/ruls3.html',
#  'https://www.rulers.org/rult.html',
#  'https://www.rulers.org/rulu.html',
#  'https://www.rulers.org/rulvw.html',
#  'https://www.rulers.org/rulyz.html',
#  'https://www.rulers.org/syn.html',
#  'https://www.rulers.org/map.html',
#  'https://www.rulers.org/intorgs1.html',
#  'https://www.rulers.org/intorgs2.html',
#  'https://www.rulers.org/fm1.html',
#  'https://www.rulers.org/fm2.html',
#  'https://www.rulers.org/fm3.html',
#  'https://www.rulers.org/fm4.html',
#  'https://www.rulers.org/relig.html',
#  'https://www.rulers.org/1996-01.html',
#  'https://www.rulers.org/1996-02.html',
#  'https://www.rulers.org/1996-03.html',
#  'https://www.rulers.org/1996-04.html',
#  'https://www.rulers.org/1996-05.html',
#  'https://www.rulers.org/1996-06.html',
#  'https://www.rulers.org/1996-07.html',
#  'https://www.rulers.org/1996-08.html',
#  'https://www.rulers.org/1996-09.html',
#  'https://www.rulers.org/1996-10.html',
#  'https://www.rulers.org/1996-11.html',
#  'https://www.rulers.org/1996-12.html',
#  'https://www.rulers.org/1997-01.html',
#  'https://www.rulers.org/1997-02.html',
#  'https://www.rulers.org/1997-03.html',
#  'https://www.rulers.org/1997-04.html',
#  'https://www.rulers.org/1997-05.html',
#  'https://www.rulers.org/1997-06.html',
#  'https://www.rulers.org/1997-07.html',
#  'https://www.rulers.org/1997-08.html',
#  'https://www.rulers.org/1997-09.html',
#  'https://www.rulers.org/1997-10.html',
#  'https://www.rulers.org/1997-11.html',
#  'https://www.rulers.org/1997-12.html',
#  'https://www.rulers.org/1998-01.html',
#  'https://www.rulers.org/1998-02.html',
#  'https://www.rulers.org/1998-03.html',
#  'https://www.rulers.org/1998-04.html',
#  'https://www.rulers.org/1998-05.html',
#  'https://www.rulers.org/1998-06.html',
#  'https://www.rulers.org/1998-07.html',
#  'https://www.rulers.org/1998-08.html',
#  'https://www.rulers.org/1998-09.html',
#  'https://www.rulers.org/1998-10.html',
#  'https://www.rulers.org/1998-11.html',
#  'https://www.rulers.org/1998-12.html',
#  'https://www.rulers.org/1999-01.html',
#  'https://www.rulers.org/1999-02.html',
#  'https://www.rulers.org/1999-03.html',
#  'https://www.rulers.org/1999-04.html',
#  'https://www.rulers.org/1999-05.html',
#  'https://www.rulers.org/1999-06.html',
#  'https://www.rulers.org/1999-07.html',
#  'https://www.rulers.org/1999-08.html',
#  'https://www.rulers.org/1999-09.html',
#  'https://www.rulers.org/1999-10.html',
#  'https://www.rulers.org/1999-11.html',
#  'https://www.rulers.org/1999-12.html',
#  'https://www.rulers.org/2000-01.html',
#  'https://www.rulers.org/2000-02.html',
#  'https://www.rulers.org/2000-03.html',
#  'https://www.rulers.org/2000-04.html',
#  'https://www.rulers.org/2000-05.html',
#  'https://www.rulers.org/2000-06.html',
#  'https://www.rulers.org/2000-07.html',
#  'https://www.rulers.org/2000-08.html',
#  'https://www.rulers.org/2000-09.html',
#  'https://www.rulers.org/2000-10.html',
#  'https://www.rulers.org/2000-11.html',
#  'https://www.rulers.org/2000-12.html',
#  'https://www.rulers.org/2001-01.html',
#  'https://www.rulers.org/2001-02.html',
#  'https://www.rulers.org/2001-03.html',
#  'https://www.rulers.org/2001-04.html',
#  'https://www.rulers.org/2001-05.html',
#  'https://www.rulers.org/2001-06.html',
#  'https://www.rulers.org/2001-07.html',
#  'https://www.rulers.org/2001-08.html',
#  'https://www.rulers.org/2001-09.html',
#  'https://www.rulers.org/2001-10.html',
#  'https://www.rulers.org/2001-11.html',
#  'https://www.rulers.org/2001-12.html',
#  'https://www.rulers.org/2002-01.html',
#  'https://www.rulers.org/2002-02.html',
#  'https://www.rulers.org/2002-03.html',
#  'https://www.rulers.org/2002-04.html',
#  'https://www.rulers.org/2002-05.html',
#  'https://www.rulers.org/2002-06.html',
#  'https://www.rulers.org/2002-07.html',
#  'https://www.rulers.org/2002-08.html',
#  'https://www.rulers.org/2002-09.html',
#  'https://www.rulers.org/2002-10.html',
#  'https://www.rulers.org/2002-11.html',
#  'https://www.rulers.org/2002-12.html',
#  'https://www.rulers.org/2003-01.html',
#  'https://www.rulers.org/2003-02.html',
#  'https://www.rulers.org/2003-03.html',
#  'https://www.rulers.org/2003-04.html',
#  'https://www.rulers.org/2003-05.html',
#  'https://www.rulers.org/2003-06.html',
#  'https://www.rulers.org/2003-07.html',
#  'https://www.rulers.org/2003-08.html',
#  'https://www.rulers.org/2003-09.html',
#  'https://www.rulers.org/2003-10.html',
#  'https://www.rulers.org/2003-11.html',
#  'https://www.rulers.org/2003-12.html',
#  'https://www.rulers.org/2004-01.html',
#  'https://www.rulers.org/2004-02.html',
#  'https://www.rulers.org/2004-03.html',
#  'https://www.rulers.org/2004-04.html',
#  'https://www.rulers.org/2004-05.html',
#  'https://www.rulers.org/2004-06.html',
#  'https://www.rulers.org/2004-07.html',
#  'https://www.rulers.org/2004-08.html',
#  'https://www.rulers.org/2004-09.html',
#  'https://www.rulers.org/2004-10.html',
#  'https://www.rulers.org/2004-11.html',
#  'https://www.rulers.org/2004-12.html',
#  'https://www.rulers.org/2005-01.html',
#  'https://www.rulers.org/2005-02.html',
#  'https://www.rulers.org/2005-03.html',
#  'https://www.rulers.org/2005-04.html',
#  'https://www.rulers.org/2005-05.html',
#  'https://www.rulers.org/2005-06.html',
#  'https://www.rulers.org/2005-07.html',
#  'https://www.rulers.org/2005-08.html',
#  'https://www.rulers.org/2005-09.html',
#  'https://www.rulers.org/2005-10.html',
#  'https://www.rulers.org/2005-11.html',
#  'https://www.rulers.org/2005-12.html',
#  'https://www.rulers.org/2006-01.html',
#  'https://www.rulers.org/2006-02.html',
#  'https://www.rulers.org/2006-03.html',
#  'https://www.rulers.org/2006-04.html',
#  'https://www.rulers.org/2006-05.html',
#  'https://www.rulers.org/2006-06.html',
#  'https://www.rulers.org/2006-07.html',
#  'https://www.rulers.org/2006-08.html',
#  'https://www.rulers.org/2006-09.html',
#  'https://www.rulers.org/2006-10.html',
#  'https://www.rulers.org/2006-11.html',
#  'https://www.rulers.org/2006-12.html',
#  'https://www.rulers.org/2007-01.html',
#  'https://www.rulers.org/2007-02.html',
#  'https://www.rulers.org/2007-03.html',
#  'https://www.rulers.org/2007-04.html',
#  'https://www.rulers.org/2007-05.html',
#  'https://www.rulers.org/2007-06.html',
#  'https://www.rulers.org/2007-07.html',
#  'https://www.rulers.org/2007-08.html',
#  'https://www.rulers.org/2007-09.html',
#  'https://www.rulers.org/2007-10.html',
#  'https://www.rulers.org/2007-11.html',
#  'https://www.rulers.org/2007-12.html',
#  'https://www.rulers.org/2008-01.html',
#  'https://www.rulers.org/2008-02.html',
#  'https://www.rulers.org/2008-03.html',
#  'https://www.rulers.org/2008-04.html',
#  'https://www.rulers.org/2008-05.html',
#  'https://www.rulers.org/2008-06.html',
#  'https://www.rulers.org/2008-07.html',
#  'https://www.rulers.org/2008-08.html',
#  'https://www.rulers.org/2008-09.html',
#  'https://www.rulers.org/2008-10.html',
#  'https://www.rulers.org/2008-11.html',
#  'https://www.rulers.org/2008-12.html',
#  'https://www.rulers.org/2009-01.html',
#  'https://www.rulers.org/2009-02.html',
#  'https://www.rulers.org/2009-03.html',
#  'https://www.rulers.org/2009-04.html',
#  'https://www.rulers.org/2009-05.html',
#  'https://www.rulers.org/2009-06.html',
#  'https://www.rulers.org/2009-07.html',
#  'https://www.rulers.org/2009-08.html',
#  'https://www.rulers.org/2009-09.html',
#  'https://www.rulers.org/2009-10.html',
#  'https://www.rulers.org/2009-11.html',
#  'https://www.rulers.org/2009-12.html',
#  'https://www.rulers.org/2010-01.html',
#  'https://www.rulers.org/2010-02.html',
#  'https://www.rulers.org/2010-03.html',
#  'https://www.rulers.org/2010-04.html',
#  'https://www.rulers.org/2010-05.html',
#  'https://www.rulers.org/2010-06.html',
#  'https://www.rulers.org/2010-07.html',
#  'https://www.rulers.org/2010-08.html',
#  'https://www.rulers.org/2010-09.html',
#  'https://www.rulers.org/2010-10.html',
#  'https://www.rulers.org/2010-11.html',
#  'https://www.rulers.org/2010-12.html',
#  'https://www.rulers.org/2011-01.html',
#  'https://www.rulers.org/2011-02.html',
#  'https://www.rulers.org/2011-03.html',
#  'https://www.rulers.org/2011-04.html',
#  'https://www.rulers.org/2011-05.html',
#  'https://www.rulers.org/2011-06.html',
#  'https://www.rulers.org/2011-07.html',
#  'https://www.rulers.org/2011-08.html',
#  'https://www.rulers.org/2011-09.html',
#  'https://www.rulers.org/2011-10.html',
#  'https://www.rulers.org/2011-11.html',
#  'https://www.rulers.org/2011-12.html',
#  'https://www.rulers.org/2012-01.html',
#  'https://www.rulers.org/2012-02.html',
#  'https://www.rulers.org/2012-03.html',
#  'https://www.rulers.org/2012-04.html',
#  'https://www.rulers.org/2012-05.html',
#  'https://www.rulers.org/2012-06.html',
#  'https://www.rulers.org/2012-07.html',
#  'https://www.rulers.org/2012-08.html',
#  'https://www.rulers.org/2012-09.html',
#  'https://www.rulers.org/2012-10.html',
#  'https://www.rulers.org/2012-11.html',
#  'https://www.rulers.org/2012-12.html',
#  'https://www.rulers.org/2013-01.html',
#  'https://www.rulers.org/2013-02.html',
#  'https://www.rulers.org/2013-03.html',
#  'https://www.rulers.org/2013-04.html',
#  'https://www.rulers.org/2013-05.html',
#  'https://www.rulers.org/2013-06.html',
#  'https://www.rulers.org/2013-07.html',
#  'https://www.rulers.org/2013-08.html',
#  'https://www.rulers.org/2013-09.html',
#  'https://www.rulers.org/2013-10.html',
#  'https://www.rulers.org/2013-11.html',
#  'https://www.rulers.org/2013-12.html',
#  'https://www.rulers.org/2014-01.html',
#  'https://www.rulers.org/2014-02.html',
#  'https://www.rulers.org/2014-03.html',
#  'https://www.rulers.org/2014-04.html',
#  'https://www.rulers.org/2014-05.html',
#  'https://www.rulers.org/2014-06.html',
#  'https://www.rulers.org/2014-07.html',
#  'https://www.rulers.org/2014-08.html',
#  'https://www.rulers.org/2014-09.html',
#  'https://www.rulers.org/2014-10.html',
#  'https://www.rulers.org/2014-11.html',
#  'https://www.rulers.org/2014-12.html',
#  'https://www.rulers.org/2015-01.html',
#  'https://www.rulers.org/2015-02.html',
#  'https://www.rulers.org/2015-03.html',
#  'https://www.rulers.org/2015-04.html',
#  'https://www.rulers.org/2015-05.html',
#  'https://www.rulers.org/2015-06.html',
#  'https://www.rulers.org/2015-07.html',
#  'https://www.rulers.org/2015-08.html',
#  'https://www.rulers.org/2015-09.html',
#  'https://www.rulers.org/2015-10.html',
#  'https://www.rulers.org/2015-11.html',
#  'https://www.rulers.org/2015-12.html',
#  'https://www.rulers.org/2016-01.html',
#  'https://www.rulers.org/2016-02.html',
#  'https://www.rulers.org/2016-03.html',
#  'https://www.rulers.org/2016-04.html',
#  'https://www.rulers.org/2016-05.html',
#  'https://www.rulers.org/2016-06.html',
#  'https://www.rulers.org/2016-07.html',
#  'https://www.rulers.org/2016-08.html',
#  'https://www.rulers.org/2016-09.html',
#  'https://www.rulers.org/2016-10.html',
#  'https://www.rulers.org/2016-11.html',
#  'https://www.rulers.org/2016-12.html',
#  'https://www.rulers.org/2017-01.html',
#  'https://www.rulers.org/2017-02.html',
#  'https://www.rulers.org/2017-03.html',
#  'https://www.rulers.org/2017-04.html',
#  'https://www.rulers.org/2017-05.html',
#  'https://www.rulers.org/2017-06.html',
#  'https://www.rulers.org/2017-07.html',
#  'https://www.rulers.org/2017-08.html',
#  'https://www.rulers.org/2017-09.html',
#  'https://www.rulers.org/2017-10.html',
#  'https://www.rulers.org/2017-11.html',
#  'https://www.rulers.org/2017-12.html',
#  'https://www.rulers.org/2018-01.html',
#  'https://www.rulers.org/2018-02.html',
#  'https://www.rulers.org/2018-03.html',
#  'https://www.rulers.org/2018-04.html',
#  'https://www.rulers.org/2018-05.html',
#  'https://www.rulers.org/2018-06.html',
#  'https://www.rulers.org/2018-07.html',
#  'https://www.rulers.org/2018-08.html',
#  'https://www.rulers.org/2018-09.html',
#  'https://www.rulers.org/2018-10.html',
#  'https://www.rulers.org/2018-11.html',
#  'https://www.rulers.org/2018-12.html',
#  'https://www.rulers.org/2019-01.html',
#  'https://www.rulers.org/2019-02.html',
#  'https://www.rulers.org/2019-03.html',
#  'https://www.rulers.org/2019-04.html',
#  'https://www.rulers.org/2019-05.html',
#  'https://www.rulers.org/2019-06.html',
#  'https://www.rulers.org/2019-07.html',
#  'https://www.rulers.org/2019-08.html',
#  'https://www.rulers.org/2019-09.html',
#  'https://www.rulers.org/2019-10.html',
#  'https://www.rulers.org/2019-11.html',
#  'https://www.rulers.org/2019-12.html',
#  'https://www.rulers.org/2020-01.html',
#  'https://www.rulers.org/2020-02.html',
#  'https://www.rulers.org/2020-03.html',
#  'https://www.rulers.org/2020-04.html',
#  'https://www.rulers.org/2020-05.html',
#  'https://www.rulers.org/2020-06.html',
#  'https://www.rulers.org/2020-07.html',
#  'https://www.rulers.org/2020-08.html',
#  'https://www.rulers.org/2020-09.html',
#  'https://www.rulers.org/2020-10.html',
#  'https://www.rulers.org/2020-11.html',
#  'https://www.rulers.org/2020-12.html',
#  'https://www.rulers.org/2021-01.html',
#  'https://www.rulers.org/2021-02.html',
#  'https://www.rulers.org/2021-03.html',
#  'https://www.rulers.org/2021-04.html',
#  'https://www.rulers.org/2021-05.html',
#  'https://www.rulers.org/2021-06.html',
#  'https://www.rulers.org/2021-07.html',
#  'https://www.rulers.org/2021-08.html',
#  'https://www.rulers.org/2021-09.html',
#  'https://www.rulers.org/2021-10.html',
#  'https://www.rulers.org/2021-11.html',
#  'https://www.rulers.org/2021-12.html',
#  'https://www.rulers.org/2022-01.html',
#  'https://www.rulers.org/2022-02.html',
#  'https://www.rulers.org/2022-03.html',
#  'https://www.rulers.org/2022-04.html',
#  'https://www.rulers.org/2022-05.html',
#  'https://www.rulers.org/2022-06.html',
#  'https://www.rulers.org/2022-07.html',
#  'https://www.rulers.org/2022-08.html',
#  'https://www.rulers.org/2022-09.html',
#  'https://www.rulers.org/2022-10.html',
#  'https://www.rulers.org/2022-11.html',
#  'https://www.rulers.org/2022-12.html',
#  'https://www.rulers.org/2023-01.html',
#  'https://www.rulers.org/2023-02.html',
#  'https://www.rulers.org/2023-03.html',
#  'https://www.rulers.org/2023-04.html',
#  'https://www.rulers.org/2023-05.html',
#  'https://www.rulers.org/2023-06.html',
#  'https://www.rulers.org/2023-07.html',
#  'https://www.rulers.org/2023-08.html',
#  'https://www.rulers.org/2023-09.html',
#  'https://www.rulers.org/2023-10.html',
#  'https://www.rulers.org/2023-11.html',
#  'https://www.rulers.org/2023-12.html',
#  'https://www.rulers.org/2024-01.html',
#  'https://www.rulers.org/indexa1.html',
#  'https://www.rulers.org/indexa2.html',
#  'https://www.rulers.org/indexa3.html',
#  'https://www.rulers.org/indexa4.html',
#  'https://www.rulers.org/indexa5.html',
#  'https://www.rulers.org/indexb1.html',
#  'https://www.rulers.org/indexb2.html',
#  'https://www.rulers.org/indexb3.html',
#  'https://www.rulers.org/indexb4.html',
#  'https://www.rulers.org/indexb5.html',
#  'https://www.rulers.org/indexc1.html',
#  'https://www.rulers.org/indexc2.html',
#  'https://www.rulers.org/indexc3.html',
#  'https://www.rulers.org/indexc4.html',
#  'https://www.rulers.org/indexd1.html',
#  'https://www.rulers.org/indexd2.html',
#  'https://www.rulers.org/indexd3.html',
#  'https://www.rulers.org/indexd4.html',
#  'https://www.rulers.org/indexe.html',
#  'https://www.rulers.org/indexf1.html',
#  'https://www.rulers.org/indexf2.html',
#  'https://www.rulers.org/indexg1.html',
#  'https://www.rulers.org/indexg2.html',
#  'https://www.rulers.org/indexg3.html',
#  'https://www.rulers.org/indexg4.html',
#  'https://www.rulers.org/indexh1.html',
#  'https://www.rulers.org/indexh2.html',
#  'https://www.rulers.org/indexh3.html',
#  'https://www.rulers.org/indexi.html',
#  'https://www.rulers.org/indexj.html',
#  'https://www.rulers.org/indexk1.html',
#  'https://www.rulers.org/indexk2.html',
#  'https://www.rulers.org/indexk3.html',
#  'https://www.rulers.org/indexl1.html',
#  'https://www.rulers.org/indexl2.html',
#  'https://www.rulers.org/indexl3.html',
#  'https://www.rulers.org/indexl4.html',
#  'https://www.rulers.org/indexm1.html',
#  'https://www.rulers.org/indexm2.html',
#  'https://www.rulers.org/indexm3.html',
#  'https://www.rulers.org/indexm4.html',
#  'https://www.rulers.org/indexm5.html',
#  'https://www.rulers.org/indexm6.html',
#  'https://www.rulers.org/indexn1.html',
#  'https://www.rulers.org/indexn2.html',
#  'https://www.rulers.org/indexo.html',
#  'https://www.rulers.org/indexp1.html',
#  'https://www.rulers.org/indexp2.html',
#  'https://www.rulers.org/indexp3.html',
#  'https://www.rulers.org/indexq.html',
#  'https://www.rulers.org/indexr1.html',
#  'https://www.rulers.org/indexr2.html',
#  'https://www.rulers.org/indexr3.html',
#  'https://www.rulers.org/indexs1.html',
#  'https://www.rulers.org/indexs2.html',
#  'https://www.rulers.org/indexs3.html',
#  'https://www.rulers.org/indexs4.html',
#  'https://www.rulers.org/indexs5.html',
#  'https://www.rulers.org/indext1.html',
#  'https://www.rulers.org/indext2.html',
#  'https://www.rulers.org/indexu.html',
#  'https://www.rulers.org/indexv.html',
#  'https://www.rulers.org/indexw1.html',
#  'https://www.rulers.org/indexw2.html',
#  'https://www.rulers.org/indexx.html',
#  'https://www.rulers.org/indexy.html',
#  'https://www.rulers.org/indexz.html',
#  'https://www.rulers.org/index0.html']

# %%
len(rulerorg_href_list)
# Out:
# 445

# %%
import re
def clean_html_string(input_text):
    clean_html = re.sub(r'<.*?>', '', input_text)
    # Remove tabs and newlines
    clean_text = clean_html.replace('\t', '').replace('\n', '')
    return clean_text

# %%
RULER_DOCUMENT_PATH = "./"
ruler_metadata = {
            "type": None,
            "source": None,
            "watchlist": None,
            "doc_local_path": None,}
ruler_html_document_data = []
for url, name in zip(rulerorg_href_list, rulerorg_html_name_list):
    try:
        ruler_html_filename = name
        ruler_html_filepath = os.path.join(RULER_DOCUMENT_PATH, ruler_html_filename)
        content_html = requests.get(url)
        new_html_content = load_and_check_data(ruler_html_filepath, content_html.text, encoding="ISO-8859-1")
        #TODO clean html
        clean_html = clean_html_string(new_html_content)
        ruler_html_content = clean_html
        _ruler_metadata = ruler_metadata.copy()
        _ruler_metadata['type'] = "Individual"
        _ruler_metadata['source'] = str(url)
        _ruler_metadata['watchlist'] = "PEP"
        _ruler_metadata['doc_local_path'] = str(ruler_html_filepath)       
        ruler_html_document_data.append((ruler_html_content, _ruler_metadata)) 
    except:
        print(new_html_content)
        break

clean_html
# Out:
# HTML content remains unchanged.
# 'Countries Ab-AmRulersCountries Ab-AmContents of this page:Afghanistan - Albania - Algeria - American SamoaAbkhazia: see under Georgia.Abu Dhabi: see under United Arab Emirates.Acre: see under Brazil.Aden: see under Yemen.AfghanistanNote: Before 1881 there were essentially four rulers\' capitals: Kabul, Herat, Kandahar, and Peshawar (the last now in Pakistan). All the rulers belong to the Abdali tribal group, whose name was changed to Dorrani on the accession of Ahmad Shah. They belong either to the Saddozay segment of the Popalzay clan (typically with the style padshah [king]) or to the Mohammadzay segment of the Barakzay clan (typically with the style amir, in full Amir al-Mo´menin [Leader of the Faithful]). The Mohammadzay also furnished the Saddozay kings frequently with top counselors, who served occasionally as regents, identified with the epithet Mohammadzay.KabulKings- Saddozay segment -   Jul 1747 - 16 Oct 1772  Ahmad Shah "Dorr-e Dorran"         (b. 1724 - d. 1772)16 Oct 1772 - 18 May 1793  Timur Shah                         (b. 1748 - d. 1793)23 May 1793 -        1801  Zaman Shah                         (b. 1770/72 - d. 1844)25 Jul 1801 -    Jul 1803  Mahmud Shah (1st time)13 Jul 1803 -        1809  Shoja` al-Molk Shah (1st time)     (b. c.1792 - d. 1842) 3 May 1808 -        1808    Qaysar Shah (in rebellion) 3 May 1809 -        1818  Mahmud Shah (2nd time)       1818 -        1819  Soltan `Ali Shah       1819 -        1823  Ayyub Shah- Mohammadzay segment -       1823                Habibollah Shah       1823 -        1826  Soltan Mohammad Khan Mohammadzay                           (regent)       1826 -        1836  Dost Mohammad Khan Mohammadzay     (b. 1789 - d. 1863)                           (regent)Emir- Mohammadzay segment -       1836 -  2 Aug 1839  Dost Mohammad Khan (1st time)      (s.a.)King- Saddozay segment - 8 May 1839 -  5 Apr 1842  Shoja` al-Molk Shah (2nd time)     (s.a.)       1841 -    Apr 1842    Mohammad Zaman Khan